# %%
from wikidataloader import WikidataQuery

# Cooks from Germany with birth places

results = WikidataQuery.search(
    filters={"P31": "Q5", "P27": "Q183", "P106": "Q156839"}, # {is_instance:human, country_of_origin:Germany, profession:cook}
    select=[("P21", "Gender"), ("P19", "City of Birth")],
    limit=15,
	default_language="en"
).to_pandas()

results
# Out:
#                        item  Gender     City_of_Birth
# 0        Christian Scharrer    male  Waldshut-Tiengen
# 1         Christian Grainer    male         Kirchdorf
# 2          Michael Hoffmann    male        Dillenburg
# 3             Björn Freitag    male     Gelsenkirchen
# 4       Peter Maria Schnurr    male           Forbach
# 5              Franz Keller    male        Oberbergen
# 6           Fritz Schilling    male         Nürtingen
# 7        Christian Grünwald    male  Wangen im Allgäu
# 8        Hans-Joachim Fuchs    male              None
# 9              Frank Oehler    male      Mussenhausen
# 10            Dieter Müller    male            Auggen
# 11          Christian Henze    male            Füssen
# 12    Jacqueline Amirfallah  female         Göttingen
# 13        Christian Jürgens    male              Unna
# 14  Doris-Katharina Hessler  female              None

# %%
# Images of stars

results = WikidataQuery.search(
    filters={"P31": "Q523"}, # {is_instance:star}
    select=[("P6879", "Temperature"), ("P18", "image_url")],
    limit=50,
	default_language="[AUTO_LANGUAGE]"
).to_pandas().dropna()

results
# Out:
#                        item Temperature  \
# 2                  KY Cygni        3500
# 6                Gamma Lupi       22210
# 8                   WASP-12   6269.3335
# 9   2MASS J00361617+1821104        1900
# 11  2MASS J15074769-1627386        1900
# 12                HD 209458        6118
#
#                                             image_url
# 2   http://commons.wikimedia.org/wiki/Special:File...
# 6   http://commons.wikimedia.org/wiki/Special:File...
# 8   http://commons.wikimedia.org/wiki/Special:File...
# 9   http://commons.wikimedia.org/wiki/Special:File...
# 11  http://commons.wikimedia.org/wiki/Special:File...
# 12  http://commons.wikimedia.org/wiki/Special:File...

# %%
# Capital cities and languages of African countries with coordinates

results = WikidataQuery.search(
    filters={"P31": "Q3624078", "P30": "Q15"}, # {is_instance:country, continent:Africa}
    negative_filters={"P31": "Q3024240", "P31": "Q28171280"}, # not: {is_instance: historical_country, is_instance:ancient_civilization}
    select=[("P36", "Capital"), ("P37", "Languages"), ("P625", "Coordinates")],
    limit=15,
	default_language="en"
).to_pandas()

results
# Out:
#             item    Capital                    Languages  \
# 0           Chad  N'Djamena                       French
# 1           Chad  N'Djamena                       Arabic
# 2       Eswatini    Mbabane                        Swazi
# 3        Somalia  Mogadishu                       Somali
# 4   South Africa  Cape Town  South African Sign Language
# 5   South Africa   Pretoria  South African Sign Language
# 6   Sierra Leone   Freetown                      English
# 7     Seychelles   Victoria           Seychellois Creole
# 8   South Africa  Cape Town               Northern Sotho
# 9   South Africa   Pretoria               Northern Sotho
# 10  South Africa  Cape Town                      Sesotho
# 11  South Africa  Cape Town                       Tsonga
# 12  South Africa   Pretoria                      Sesotho
# 13  South Africa   Pretoria                       Tsonga
# 14       Somalia  Mogadishu                       Arabic
#
#                     Coordinates
# 0         Point(19.4 15.466667)
# 1         Point(19.4 15.466667)
# 2   Point(31.433333 -26.483333)
# 3               Point(47.0 6.0)
# 4             Point(24.0 -29.0)
# 5             Point(24.0 -29.0)
# 6              Point(-12.1 8.5)
# 7         Point(52.766667 -7.1)
# 8             Point(24.0 -29.0)
# 9             Point(24.0 -29.0)
# 10            Point(24.0 -29.0)
# 11            Point(24.0 -29.0)
# 12            Point(24.0 -29.0)
# 13            Point(24.0 -29.0)
# 14              Point(47.0 6.0)

# %%
# List of phrases

results = WikidataQuery.search(
    filters={"P31": "Q187931"}, # {is_instance:phrase}
    limit=15,
	default_language="en"
).to_pandas()

list(results["item"])
# Out:
# ['To be, or not to be',
#  'genius loci',
#  'Item',
#  'a picture is worth a thousand words',
#  'Mulus',
#  'Minus',
#  'Cash is king',
#  'That that is is that that is not is not is that it it is.',
#  'Studia humanitatis',
#  'Chorismos',
#  'Concursus Dei',
#  'Condictio causa data non secuta',
#  'Condictio certae pecuniae',
#  'Condictio certae rei',
#  'Condictio ob causam finitam']
